# %% [markdown]
# ### 90803 Final Project
# # Classification of cities into Growth Categories
#
# **Team 14**
#
# Chi-Shiun Tsai & Colton Lapp

# %% [markdown]
# ### Import Modules

# %%
import os
import numpy as np
import pandas as pd
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import math
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import RobustScaler
import geopandas as gpd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import load_iris
import warnings

pd.set_option('display.max_columns', 500)

# %% [markdown]
# #### Set Seed

# %%
seed = 0

# %% [markdown]
# ### Read in Data

# %%
#Set Base Dir
base_dir = os.getcwd().split('/')
base_dir = '/'.join(base_dir[0:-1])
base_dir
df = pd.read_csv(base_dir + '/Team14_CL_CT_MG/data/data_all.csv', low_memory=False)
df.head()
# Out:
#                            Name  Population 2020  Median Household Income  \
# 0       New York city, New York          8379552                  67046.0
# 1  Los Angeles city, California          3973278                  65290.0
# 2        Chicago city, Illinois          2699347                  62097.0
# 3           Houston city, Texas          2313238                  53600.0
# 4         Phoenix city, Arizona          1658422                  60914.0
#
#    Median Home Value  Median Gross Rent  Renter Household  \
# 0           635200.0             1489.0         2143429.0
# 1           670700.0             1523.0          884176.0
# 2           267600.0             1154.0          590848.0
# 3           186800.0             1086.0          499608.0
# 4           250800.0             1100.0          258077.0
#
#    Total Housing Units  Race: White Alone  Hispanic or Latino  \
# 0            42.002186          41.330205           28.925997
# 1            38.099297          48.930480           48.066307
# 2            45.110392          47.731581           28.628813
# 3            42.481318          51.539271           44.471948
# 4            37.805637          68.233176           42.647046
#
#    Population Age 25 or Older: Bachelor`s Degree  \
# 0                                      16.000569
# 1                                      16.225771
# 2                                      16.758127
# 3                                      13.576078
# 4                                      11.954557
#
#    Population Age 25 or Older: Doctorate Degree  \
# 0                                      1.125072
# 1                                      1.007329
# 2                                      1.200438
# 3                                      1.126473
# 4                                      0.754512
#
#    Pop 5-17 Speak only English at Home  \
# 0                             7.664813
# 1                             5.683670
# 2                             8.816058
# 3                             8.046470
# 4                            11.002447
#
#    Population Age 15 or Older Never Married  \
# 0                                 17.610035
# 1                                 19.986897
# 2                                 20.245897
# 3                                 17.088946
# 4                                 16.492967
#
#    Population Age 15 or Older Never Married 2  Population Age 65 or more  \
# 0                                   18.069295                  14.947255
# 1                                   17.982834                  12.855557
# 2                                   19.983537                  12.676177
# 3                                   15.180669                  10.985813
# 4                                   14.118542                  10.974408
#
#    Pop 65 or more Living in Nonfamily Households  \
# 0                                       4.979001
# 1                                       3.889962
# 2                                       4.820647
# 3                                       3.587785
# 4                                       3.490125
#
#    Females 20-64 w Own Children 0-17  Workers Age 16 or more  \
# 0                           1.908419               46.830821
# 1                           1.788574               49.252959
# 2                           1.800250               49.382610
# 3                           2.314159               47.686144
# 4                           2.569792               48.881527
#
#    Workers 16 or more who Took Public Transportation to work  \
# 0                                          24.736883
# 1                                           4.056122
# 2                                          12.919050
# 3                                           1.748501
# 4                                           1.325778
#
#    Workers 16 or more who Worked at Home  \
# 0                               3.465794
# 1                               4.517605
# 2                               4.194570
# 3                               2.939646
# 4                               4.060667
#
#    Workers 16 or more who Drove Alone to Work  \
# 0                                   10.448387
# 1                                   33.341664
# 2                                   23.775417
# 3                                   36.207040
# 4                                   35.624769
#
#    Employed in Professional/Scientific/Technical Services  \
# 0                                           4.848242
# 1                                           4.703748
# 2                                           6.130186
# 3                                           4.086998
# 4                                           3.587989
#
#    Employed in Accommodation/Food Services  \
# 0                                 3.531358
# 1                                 4.288298
# 2                                 4.004228
# 3                                 3.904484
# 4                                 4.214126
#
#    Employed in Health Care/Social Assistance  \
# 0                                   8.708186
# 1                                   6.098239
# 2                                   7.006176
# 3                                   5.408134
# 4                                   6.030914
#
#    Employed in Arts/Entertainment/Recreation  \
# 0                                   1.403011
# 1                                   2.086111
# 2                                   1.199698
# 3                                   0.727076
# 4                                   0.925096
#
#    Male 16+: Private For-Profit Self-Emp Inc Bus  \
# 0                                       1.143271
# 1                                       1.660996
# 2                                       1.064406
# 3                                       0.958916
# 4                                       1.144582
#
#    Male 16+: Private Not-For-Profit Worker  Civilian Population 18+: Veteran  \
# 0                                 1.902047                          1.705306
# 1                                 1.278365                          2.068393
# 2                                 2.110918                          2.475895
# 3                                 1.097639                          2.983826
# 4                                 1.225804                          4.415402
#
#    Population 35-64: Medicaid Coverage Only  \
# 0                                  8.383276
# 1                                  7.988391
# 2                                  5.359926
# 3                                  2.628869
# 4                                  5.078864
#
#    Population 35-64: No Health Insurance Coverage  \
# 0                                        3.427486
# 1                                        5.480588
# 2                                        4.764597
# 3                                       10.073672
# 4                                        6.408743
#
#    Households with No Internet Acces  Households Receiving Food Stamps/SNAP  \
# 0                           5.030627                               7.244218
# 1                           3.824172                               3.640193
# 2                           5.445095                               7.012289
# 3                           5.207333                               5.392571
# 4                           3.939890                               4.255793
#
#    Households Below the Poverty Leve  Gross Rent 50% + of Household Income  \
# 0                           6.556830                              6.763679
# 1                           5.838303                              6.734288
# 2                           6.614933                              5.035996
# 3                           6.563527                              5.208932
# 4                           4.791905                              3.291020
#
#    Owner Households by Year Moved In: 2017 or Later  \
# 0                                          0.208245
# 1                                          0.256715
# 2                                          0.455777
# 3                                          0.410939
# 4                                          0.706636
#
#    Total Vacant Housing Units  Housing Units Built in 2014 or Later  state  \
# 0                    3.913145                              0.719466     36
# 1                    2.800433                              0.887101      6
# 2                    5.058372                              0.868655     17
# 3                    4.663031                              2.628869     48
# 4                    2.782283                              1.114433      4
#
#      GEOID  Population 2019  Pop Chng %   land_area  water_area  \
# 0  3651000          8419316   -0.472295   777982727   434642000
# 1   644000          3966936    0.159871  1214591312    87468461
# 2  1714000          2709534   -0.375969   588881854    17621529
# 3  4835000          2310432    0.121449  1658093679    81248080
# 4   455000          1633017    1.555709  1340766401     3236736
#
#    cases_per_100K  deaths_per_100K
# 0     5913.616647       220.640533
# 1     6178.068445        67.066531
# 2     7499.869841       133.847542
# 3     4991.616106        57.677759
# 4     7307.164034       116.139965

# %% [markdown]
# ## Set Up Data

# %% [markdown]
# ### Adjust Row Names
# Note: If we want to include state effects, we could keep that column and create boolean values out of oit

# %%
#Set row equal to name
df.set_index('Name', inplace=True, drop=True)

#Drop GEOID and STATE column
df = df.drop( ['GEOID', 'state'], axis=1)
df.head(1)
# Out:
#                          Population 2020  Median Household Income  \
# Name
# New York city, New York          8379552                  67046.0
#
#                          Median Home Value  Median Gross Rent  \
# Name
# New York city, New York           635200.0             1489.0
#
#                          Renter Household  Total Housing Units  \
# Name
# New York city, New York         2143429.0            42.002186
#
#                          Race: White Alone  Hispanic or Latino  \
# Name
# New York city, New York          41.330205           28.925997
#
#                          Population Age 25 or Older: Bachelor`s Degree  \
# Name
# New York city, New York                                      16.000569
#
#                          Population Age 25 or Older: Doctorate Degree  \
# Name
# New York city, New York                                      1.125072
#
#                          Pop 5-17 Speak only English at Home  \
# Name
# New York city, New York                             7.664813
#
#                          Population Age 15 or Older Never Married  \
# Name
# New York city, New York                                 17.610035
#
#                          Population Age 15 or Older Never Married 2  \
# Name
# New York city, New York                                   18.069295
#
#                          Population Age 65 or more  \
# Name
# New York city, New York                  14.947255
#
#                          Pop 65 or more Living in Nonfamily Households  \
# Name
# New York city, New York                                       4.979001
#
#                          Females 20-64 w Own Children 0-17  \
# Name
# New York city, New York                           1.908419
#
#                          Workers Age 16 or more  \
# Name
# New York city, New York               46.830821
#
#                          Workers 16 or more who Took Public Transportation to work  \
# Name
# New York city, New York                                          24.736883
#
#                          Workers 16 or more who Worked at Home  \
# Name
# New York city, New York                               3.465794
#
#                          Workers 16 or more who Drove Alone to Work  \
# Name
# New York city, New York                                   10.448387
#
#                          Employed in Professional/Scientific/Technical Services  \
# Name
# New York city, New York                                           4.848242
#
#                          Employed in Accommodation/Food Services  \
# Name
# New York city, New York                                 3.531358
#
#                          Employed in Health Care/Social Assistance  \
# Name
# New York city, New York                                   8.708186
#
#                          Employed in Arts/Entertainment/Recreation  \
# Name
# New York city, New York                                   1.403011
#
#                          Male 16+: Private For-Profit Self-Emp Inc Bus  \
# Name
# New York city, New York                                       1.143271
#
#                          Male 16+: Private Not-For-Profit Worker  \
# Name
# New York city, New York                                 1.902047
#
#                          Civilian Population 18+: Veteran  \
# Name
# New York city, New York                          1.705306
#
#                          Population 35-64: Medicaid Coverage Only  \
# Name
# New York city, New York                                  8.383276
#
#                          Population 35-64: No Health Insurance Coverage  \
# Name
# New York city, New York                                        3.427486
#
#                          Households with No Internet Acces  \
# Name
# New York city, New York                           5.030627
#
#                          Households Receiving Food Stamps/SNAP  \
# Name
# New York city, New York                               7.244218
#
#                          Households Below the Poverty Leve  \
# Name
# New York city, New York                            6.55683
#
#                          Gross Rent 50% + of Household Income  \
# Name
# New York city, New York                              6.763679
#
#                          Owner Households by Year Moved In: 2017 or Later  \
# Name
# New York city, New York                                          0.208245
#
#                          Total Vacant Housing Units  \
# Name
# New York city, New York                    3.913145
#
#                          Housing Units Built in 2014 or Later  state  \
# Name
# New York city, New York                              0.719466     36
#
#                          Population 2019  Pop Chng %  land_area  water_area  \
# Name
# New York city, New York          8419316   -0.472295  777982727   434642000
#
#                          cases_per_100K  deaths_per_100K
# Name
# New York city, New York     5913.616647       220.640533

# %% [markdown]
# ### Create Boolean Target Variable

# %%
# define a function to apply to the 'population' column
def growth_function(row):
    if row['Pop Chng %'] > 0:
        return 1
    else:
        return 0

# create new 'growth' column using the apply function
df['Growing'] = df.apply(lambda row: growth_function(row), axis=1)
df[['Pop Chng %', 'Growing']].head(5)
# Out:
#                               Pop Chng %  Growing
# Name
# New York city, New York        -0.472295        0
# Los Angeles city, California    0.159871        1
# Chicago city, Illinois         -0.375969        0
# Houston city, Texas             0.121449        1
# Phoenix city, Arizona           1.555709        1

# %% [markdown]
# ## Train Test Split
# Should we keep Population as a feature? I could see arguments for and against

# %%
y = df[['Growing']]
X = df.drop(['Growing', 'Pop Chng %', 'Population 2019'], axis=1)

X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.25, random_state=seed)
X_train.head(3)
# Out:
#                            Population 2020  Median Household Income  \
# Name
# Deltona city, Florida                91847                  56760.0
# Encampment town, Wyoming               432                  43170.0
# Lamberton city, Minnesota              831                  50357.0
#
#                            Median Home Value  Median Gross Rent  \
# Name
# Deltona city, Florida               170000.0             1189.0
# Encampment town, Wyoming            184000.0             1031.0
# Lamberton city, Minnesota            64100.0              600.0
#
#                            Renter Household  Total Housing Units  \
# Name
# Deltona city, Florida                6883.0            36.063236
# Encampment town, Wyoming               63.0            78.703704
# Lamberton city, Minnesota              79.0            51.985560
#
#                            Race: White Alone  Hispanic or Latino  \
# Name
# Deltona city, Florida              70.350692           36.911385
# Encampment town, Wyoming          100.000000            0.000000
# Lamberton city, Minnesota          93.742479            3.008424
#
#                            Population Age 25 or Older: Bachelor`s Degree  \
# Name
# Deltona city, Florida                                           8.532668
# Encampment town, Wyoming                                       14.351852
# Lamberton city, Minnesota                                       6.859206
#
#                            Population Age 25 or Older: Doctorate Degree  \
# Name
# Deltona city, Florida                                          0.124119
# Encampment town, Wyoming                                       1.620370
# Lamberton city, Minnesota                                      0.240674
#
#                            Pop 5-17 Speak only English at Home  \
# Name
# Deltona city, Florida                                14.470805
# Encampment town, Wyoming                             24.305556
# Lamberton city, Minnesota                            17.689531
#
#                            Population Age 15 or Older Never Married  \
# Name
# Deltona city, Florida                                     13.635720
# Encampment town, Wyoming                                  11.342593
# Lamberton city, Minnesota                                 11.793020
#
#                            Population Age 15 or Older Never Married 2  \
# Name
# Deltona city, Florida                                       11.849053
# Encampment town, Wyoming                                     7.870370
# Lamberton city, Minnesota                                    7.220217
#
#                            Population Age 65 or more  \
# Name
# Deltona city, Florida                      16.122465
# Encampment town, Wyoming                   18.287037
# Lamberton city, Minnesota                  25.631769
#
#                            Pop 65 or more Living in Nonfamily Households  \
# Name
# Deltona city, Florida                                           3.712696
# Encampment town, Wyoming                                        9.722222
# Lamberton city, Minnesota                                       9.386282
#
#                            Females 20-64 w Own Children 0-17  \
# Name
# Deltona city, Florida                               1.709364
# Encampment town, Wyoming                            0.462963
# Lamberton city, Minnesota                           2.647413
#
#                            Workers Age 16 or more  \
# Name
# Deltona city, Florida                   43.882762
# Encampment town, Wyoming                46.296296
# Lamberton city, Minnesota               42.839952
#
#                            Workers 16 or more who Took Public Transportation to work  \
# Name
# Deltona city, Florida                                               0.107788
# Encampment town, Wyoming                                            0.000000
# Lamberton city, Minnesota                                           0.000000
#
#                            Workers 16 or more who Worked at Home  \
# Name
# Deltona city, Florida                                   2.962536
# Encampment town, Wyoming                                6.250000
# Lamberton city, Minnesota                               2.166065
#
#                            Workers 16 or more who Drove Alone to Work  \
# Name
# Deltona city, Florida                                       36.378978
# Encampment town, Wyoming                                    34.259259
# Lamberton city, Minnesota                                   31.768953
#
#                            Employed in Professional/Scientific/Technical Services  \
# Name
# Deltona city, Florida                                               1.976112
# Encampment town, Wyoming                                            2.083333
# Lamberton city, Minnesota                                           0.481348
#
#                            Employed in Accommodation/Food Services  \
# Name
# Deltona city, Florida                                     3.192265
# Encampment town, Wyoming                                  2.546296
# Lamberton city, Minnesota                                 0.000000
#
#                            Employed in Health Care/Social Assistance  \
# Name
# Deltona city, Florida                                       6.445502
# Encampment town, Wyoming                                    9.490741
# Lamberton city, Minnesota                                   8.182912
#
#                            Employed in Arts/Entertainment/Recreation  \
# Name
# Deltona city, Florida                                       1.210709
# Encampment town, Wyoming                                    2.314815
# Lamberton city, Minnesota                                   3.249097
#
#                            Male 16+: Private For-Profit Self-Emp Inc Bus  \
# Name
# Deltona city, Florida                                           1.009287
# Encampment town, Wyoming                                        0.000000
# Lamberton city, Minnesota                                       0.722022
#
#                            Male 16+: Private Not-For-Profit Worker  \
# Name
# Deltona city, Florida                                     0.765403
# Encampment town, Wyoming                                  1.157407
# Lamberton city, Minnesota                                 1.925391
#
#                            Civilian Population 18+: Veteran  \
# Name
# Deltona city, Florida                              7.142313
# Encampment town, Wyoming                           7.870370
# Lamberton city, Minnesota                          6.979543
#
#                            Population 35-64: Medicaid Coverage Only  \
# Name
# Deltona city, Florida                                      3.340338
# Encampment town, Wyoming                                   0.000000
# Lamberton city, Minnesota                                  2.647413
#
#                            Population 35-64: No Health Insurance Coverage  \
# Name
# Deltona city, Florida                                            5.348024
# Encampment town, Wyoming                                         1.851852
# Lamberton city, Minnesota                                        0.601685
#
#                            Households with No Internet Acces  \
# Name
# Deltona city, Florida                               3.353403
# Encampment town, Wyoming                            9.722222
# Lamberton city, Minnesota                          10.348977
#
#                            Households Receiving Food Stamps/SNAP  \
# Name
# Deltona city, Florida                                   6.073143
# Encampment town, Wyoming                                0.000000
# Lamberton city, Minnesota                               1.805054
#
#                            Households Below the Poverty Leve  \
# Name
# Deltona city, Florida                               3.726850
# Encampment town, Wyoming                            3.703704
# Lamberton city, Minnesota                           3.850782
#
#                            Gross Rent 50% + of Household Income  \
# Name
# Deltona city, Florida                                  1.959781
# Encampment town, Wyoming                               0.000000
# Lamberton city, Minnesota                              0.240674
#
#                            Owner Households by Year Moved In: 2017 or Later  \
# Name
# Deltona city, Florida                                              0.687012
# Encampment town, Wyoming                                           4.861111
# Lamberton city, Minnesota                                          1.684717
#
#                            Total Vacant Housing Units  \
# Name
# Deltona city, Florida                        2.763291
# Encampment town, Wyoming                    28.472222
# Lamberton city, Minnesota                   10.348977
#
#                            Housing Units Built in 2014 or Later  state  \
# Name
# Deltona city, Florida                                  0.182913     12
# Encampment town, Wyoming                               3.009259     56
# Lamberton city, Minnesota                              1.083032     27
#
#                            land_area  water_area  cases_per_100K  \
# Name
# Deltona city, Florida       96537108     9151400     4081.800819
# Encampment town, Wyoming     4136211           0     6276.122869
# Lamberton city, Minnesota    1979346           0     8609.227934
#
#                            deaths_per_100K
# Name
# Deltona city, Florida            82.218320
# Encampment town, Wyoming         99.515690
# Lamberton city, Minnesota       171.131442

# %% [markdown]
# ## Check for Class Imbalances

# %%
y_train.value_counts()
# Out:
# Growing
# 1          7732
# 0          6889
# dtype: int64

# %% [markdown]
# **Results: Looks pretty balanced!**

# %% [markdown]
# # Scale Datasets

# %%
#create a RobustScaler object
scaler = RobustScaler()
#Fit
scaler.fit(X_train)

#Transform X_train and X_test
X_train_RS = pd.DataFrame(  scaler.transform(X_train), columns = X_train.columns)
X_train_RS.set_index( X_train.index , drop=True, inplace=True)

X_test_RS =  pd.DataFrame( scaler.transform(X_test), columns = X_test.columns)
X_test_RS.set_index( X_test.index , drop=True, inplace=True)

X_train_RS.head(3)
# Out:
#                            Population 2020  Median Household Income  \
# Name
# Deltona city, Florida            20.223561                 0.230490
# Encampment town, Wyoming         -0.172468                -0.305965
# Lamberton city, Minnesota        -0.083445                -0.022263
#
#                            Median Home Value  Median Gross Rent  \
# Name
# Deltona city, Florida               0.573267           1.347826
# Encampment town, Wyoming            0.711881           0.889855
# Lamberton city, Minnesota          -0.475248          -0.359420
#
#                            Renter Household  Total Housing Units  \
# Name
# Deltona city, Florida             11.584906            -0.797428
# Encampment town, Wyoming          -0.113208             2.583286
# Lamberton city, Minnesota         -0.085763             0.464960
#
#                            Race: White Alone  Hispanic or Latino  \
# Name
# Deltona city, Florida              -1.072642            3.836635
# Encampment town, Wyoming            0.488792           -0.391156
# Lamberton city, Minnesota           0.159250           -0.046574
#
#                            Population Age 25 or Older: Bachelor`s Degree  \
# Name
# Deltona city, Florida                                           0.026752
# Encampment town, Wyoming                                        0.771238
# Lamberton city, Minnesota                                      -0.187345
#
#                            Population Age 25 or Older: Doctorate Degree  \
# Name
# Deltona city, Florida                                         -0.002509
# Encampment town, Wyoming                                       2.339123
# Lamberton city, Minnesota                                      0.179898
#
#                            Pop 5-17 Speak only English at Home  \
# Name
# Deltona city, Florida                                -0.055030
# Encampment town, Wyoming                              1.312698
# Lamberton city, Minnesota                             0.392601
#
#                            Population Age 15 or Older Never Married  \
# Name
# Deltona city, Florida                                      0.228548
# Encampment town, Wyoming                                  -0.145871
# Lamberton city, Minnesota                                 -0.072326
#
#                            Population Age 15 or Older Never Married 2  \
# Name
# Deltona city, Florida                                        0.338377
# Encampment town, Wyoming                                    -0.354898
# Lamberton city, Minnesota                                   -0.468186
#
#                            Population Age 65 or more  \
# Name
# Deltona city, Florida                      -0.157014
# Encampment town, Wyoming                    0.075197
# Lamberton city, Minnesota                   0.863125
#
#                            Pop 65 or more Living in Nonfamily Households  \
# Name
# Deltona city, Florida                                          -0.425781
# Encampment town, Wyoming                                        0.941565
# Lamberton city, Minnesota                                       0.865129
#
#                            Females 20-64 w Own Children 0-17  \
# Name
# Deltona city, Florida                              -0.102909
# Encampment town, Wyoming                           -0.785334
# Lamberton city, Minnesota                           0.410687
#
#                            Workers Age 16 or more  \
# Name
# Deltona city, Florida                   -0.106138
# Encampment town, Wyoming                 0.105449
# Lamberton city, Minnesota               -0.197559
#
#                            Workers 16 or more who Took Public Transportation to work  \
# Name
# Deltona city, Florida                                               0.414025
# Encampment town, Wyoming                                            0.000000
# Lamberton city, Minnesota                                           0.000000
#
#                            Workers 16 or more who Worked at Home  \
# Name
# Deltona city, Florida                                   0.473271
# Encampment town, Wyoming                                1.716299
# Lamberton city, Minnesota                               0.172117
#
#                            Workers 16 or more who Drove Alone to Work  \
# Name
# Deltona city, Florida                                        0.049265
# Encampment town, Wyoming                                    -0.148573
# Lamberton city, Minnesota                                   -0.381000
#
#                            Employed in Professional/Scientific/Technical Services  \
# Name
# Deltona city, Florida                                               0.341400
# Encampment town, Wyoming                                            0.388896
# Lamberton city, Minnesota                                          -0.320731
#
#                            Employed in Accommodation/Food Services  \
# Name
# Deltona city, Florida                                     0.238139
# Encampment town, Wyoming                                 -0.001828
# Lamberton city, Minnesota                                -0.947736
#
#                            Employed in Health Care/Social Assistance  \
# Name
# Deltona city, Florida                                       0.065091
# Encampment town, Wyoming                                    0.856183
# Lamberton city, Minnesota                                   0.516435
#
#                            Employed in Arts/Entertainment/Recreation  \
# Name
# Deltona city, Florida                                       0.748613
# Encampment town, Wyoming                                    1.796509
# Lamberton city, Minnesota                                   2.683229
#
#                            Male 16+: Private For-Profit Self-Emp Inc Bus  \
# Name
# Deltona city, Florida                                           0.287473
# Encampment town, Wyoming                                       -0.467118
# Lamberton city, Minnesota                                       0.072699
#
#                            Male 16+: Private Not-For-Profit Worker  \
# Name
# Deltona city, Florida                                    -0.053789
# Encampment town, Wyoming                                  0.241875
# Lamberton city, Minnesota                                 0.821116
#
#                            Civilian Population 18+: Veteran  \
# Name
# Deltona city, Florida                              0.344711
# Encampment town, Wyoming                           0.535370
# Lamberton city, Minnesota                          0.302086
#
#                            Population 35-64: Medicaid Coverage Only  \
# Name
# Deltona city, Florida                                      0.113736
# Encampment town, Wyoming                                  -0.720882
# Lamberton city, Minnesota                                 -0.059398
#
#                            Population 35-64: No Health Insurance Coverage  \
# Name
# Deltona city, Florida                                            0.518272
# Encampment town, Wyoming                                        -0.327410
# Lamberton city, Minnesota                                       -0.629811
#
#                            Households with No Internet Acces  \
# Name
# Deltona city, Florida                              -0.500498
# Encampment town, Wyoming                            0.613236
# Lamberton city, Minnesota                           0.722838
#
#                            Households Receiving Food Stamps/SNAP  \
# Name
# Deltona city, Florida                                   0.294229
# Encampment town, Wyoming                               -0.828715
# Lamberton city, Minnesota                              -0.494954
#
#                            Households Below the Poverty Leve  \
# Name
# Deltona city, Florida                              -0.256440
# Encampment town, Wyoming                           -0.261054
# Lamberton city, Minnesota                          -0.231741
#
#                            Gross Rent 50% + of Household Income  \
# Name
# Deltona city, Florida                                  0.124794
# Encampment town, Wyoming                              -0.605695
# Lamberton city, Minnesota                             -0.515986
#
#                            Owner Households by Year Moved In: 2017 or Later  \
# Name
# Deltona city, Florida                                              0.542316
# Encampment town, Wyoming                                           5.989515
# Lamberton city, Minnesota                                          1.844321
#
#                            Total Vacant Housing Units  \
# Name
# Deltona city, Florida                       -0.379820
# Encampment town, Wyoming                     3.223304
# Lamberton city, Minnesota                    0.683319
#
#                            Housing Units Built in 2014 or Later     state  \
# Name
# Deltona city, Florida                                 -0.066037 -0.708333
# Encampment town, Wyoming                               2.331647  1.125000
# Lamberton city, Minnesota                              0.697564 -0.083333
#
#                            land_area  water_area  cases_per_100K  \
# Name
# Deltona city, Florida        9.03334   67.119710       -0.899299
# Encampment town, Wyoming     0.01498   -0.056882       -0.146699
# Lamberton city, Minnesota   -0.19553   -0.056882        0.653500
#
#                            deaths_per_100K
# Name
# Deltona city, Florida            -0.240080
# Encampment town, Wyoming         -0.033962
# Lamberton city, Minnesota         0.819420

# %% [markdown]
# # Baseline Classification Using Logistic Regression

# %%
LR_baseline = LogisticRegression(random_state=seed)
CVs_LR_baseline = cross_val_score(LR_baseline, X_train_RS, y_train.squeeze(), cv=10, scoring = 'f1') 

print("Mean CV F1 Score: ", np.mean(CVs_LR_baseline))
print("Std Dev CV F1 Score: ", np.std(CVs_LR_baseline))
# Out:
# Mean CV F1 Score:  0.5409586220298395
# Std Dev CV F1 Score:  0.04316028366748058

# %% [markdown]
# ## Tune Parameters of Logistic Regression
# ### Use GridSearch CV

# %%
#Define new LogReg
LR_GS = LogisticRegression(random_state=seed)

# define parameter grid for grid search
param_grid = {
    'penalty': ['l1', None],
    'C': [0.1, 1, 10],
    'solver': ['newton-cg', 'lbfgs', 'liblinear'],
    'max_iter': [100, 300]
}

# set warnings to false
warnings.filterwarnings('ignore')

#GridSearchCV object
GS = GridSearchCV(estimator=LR_GS, param_grid=param_grid, cv=5)
GS.fit(X_train_RS, y_train.squeeze())

# set warnings back to true
warnings.filterwarnings('default')

#Print Optimal Parameters
best_params = GS.best_params_
print("Optimal parameters:",best_params)

#Set Best Parameters
LR_GS.set_params(**best_params)

#Get CV Score
CVs_LR_GS = cross_val_score(LR_GS, X_train_RS, y_train.squeeze(), cv=10, scoring = 'f1') 
print("Mean CV F1 Score: ", np.mean(CVs_LR_GS))
print("Std Dev CV F1 Score: ", np.std(CVs_LR_GS))
# Out:
# Optimal parameters: {'C': 0.1, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# Mean CV F1 Score:  0.6417809055741956
# Std Dev CV F1 Score:  0.016309604491181393

# %% [markdown]
# # References:
# - https://stackoverflow.com/questions/26886653/create-new-column-based-on-values-from-other-columns-apply-a-function-of-multi
# - https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html
# - https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html
# - https://stackoverflow.com/questions/75220289/difference-between-gridsearch-best-estimator-and-best-params
